# %%
from hdx.api.configuration import Configuration
from hdx.data.dataset import Dataset

import pandas as pd

# %%
# Initialize for production (read-only)
Configuration.create(hdx_site="prod", user_agent="BlossomGroup6", hdx_read_only=True)
# Out:
# 'https://data.humdata.org'

# %%
datasets = Dataset.search_in_hdx("Ghana food prices")
