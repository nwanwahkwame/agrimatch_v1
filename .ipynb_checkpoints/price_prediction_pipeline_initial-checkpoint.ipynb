# %%
import pandas as pd

# %%
df = pd.read_csv('crop_table/Cassava.csv')

# %%
df.head(1)
# Out:
#          date  year  month  day   region    city market_sold_at  market_id  \
# 0  2006-01-15  2006      1   15  ASHANTI  Kumasi            KMA        215
#
#    latitude  longitude  unit(KG)  actual  pricetype  cedi_price
# 0      6.68      -1.62      91.0  actual  Wholesale       10.31

# %%
df.describe()
# Out:
#               year        month     day    market_id     latitude  \
# count  2997.000000  2997.000000  2997.0  2997.000000  2997.000000
# mean   2015.820153     6.410744    15.0   361.958959     6.958829
# std       4.950154     3.460022     0.0   502.966421     1.651465
# min    2006.000000     1.000000    15.0   209.000000     4.930000
# 25%    2011.000000     3.000000    15.0   212.000000     5.550000
# 50%    2016.000000     6.000000    15.0   216.000000     6.680000
# 75%    2020.000000     9.000000    15.0   220.000000     7.580000
# max    2023.000000    12.000000    15.0  2802.000000    11.050000
#
#          longitude  unit(KG)   cedi_price
# count  2997.000000    2304.0  2997.000000
# mean     -1.090604      91.0    87.546420
# std       0.841906       0.0   236.154288
# min      -2.880000      91.0     0.700000
# 25%      -1.700000      91.0    10.000000
# 50%      -1.240000      91.0    30.000000
# 75%      -0.250000      91.0    77.350000
# ...

# %%
df.dtypes
# Out:
# date               object
# year                int64
# month               int64
# day                 int64
# region             object
# city               object
# market_sold_at     object
# market_id           int64
# latitude          float64
# longitude         float64
# unit(KG)          float64
# actual             object
# pricetype          object
# cedi_price        float64
# dtype: object
