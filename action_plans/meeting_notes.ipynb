# %% [markdown]
# ### Meeting 1
# ---
#     Suggested Name: Agri Mall
#     Suggested Format: Mobile or Web App
#
# ### Goal (Subject to change): Link farmers to agricultural services like;
#
#     - vet services,
#     - mechanization services,
#     - consultation services and
#     - input suppliers (seeds, tools and equipment)
#
# ### Agri Mall Future Roadmap:
#     - Seasonally available crops
#     - Events that are ongoing
#     - Weather forecast
#     - Vaccinations reminder
#     - Best ag practices
#     - Forums and seminars

# %% [markdown]
# ### Meeting 2
# ---
#     Python - Code integration
#     SQL - For database management
#     Power BI - For dashboards
#     Flask or Streamlit - Mobile of web app user interface
#
# The issue now is how to obtain data to back whatever we will do. If we're going to need a database, we will need data.

# %% [markdown]
# ### Meeting 3
# ---
#     - Yes, feature importance is widely used in time series forecasting and classification, but it requires specialized techniques to handle sequential data and temporal dependencies.
#     - We may have to weigh the importance of market vs city.
#     - Replace missing values in unit(KG) with 1. ✅
#     - Standardize the prices according to kilograms. ✅
#     - Possible use of LabelEnconder on region, city and market sold at.

# %% [markdown]
# ### Meeting 4
# ---
#     - Drop some crops, especially Plantain and its variant, due to standardizing issues.
#     - Drop crops should problems arise.
