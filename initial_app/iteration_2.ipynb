# %%
print("Welcome to Farm Sage: Connecting Farmers and Buyers Across Ghana.\n")
# Out:
# Welcome to Farm Sage: Connecting Farmers and Buyers Across Ghana.

# %%
name = input("What is your name? ").split()
first_name = name[0]
last_name = " ".join(name[1:])
print(f"Welcome, {name[0]}.\n")
# Out:
# Welcome, Charles.

# %%
last_name
# Out:
# 'Kwame Ansah Boadi Nti Nwanwah'

# %%
roles = ["Farmer", "Buyer"]

print("\nWhat role do you play? \n")

while True:
    for index, type_of_role in enumerate(roles, start=1):
        print(f"{index}:{type_of_role}")
    try:
        role = input("\nResponse: ")
        role = int(role)
        if not (1 <= role <= len(roles)):
            print("\nPlease enter a valid response.\n")
            continue
        else:
            choice = roles[role-1]
            print(f"\nInput received: {choice}")
            break
    except ValueError:
        print("\nInvalid input. Please enter a corresponding number.\n")
# Out:
# Welcome to Farm Sage: Connecting Farmers and Buyers Across Ghana.
#
# What role do you play?
#
# 1:Farmer
# 2:Buyer
#
# Input received: Farmer

# %%
while True:
    try:
        phone_number = input("Starting with 0XX, enter your phone number: ")
        if len(phone_number) == 10:
            phone_number = int(phone_number)
            print(f"\nPhone number received: {phone_number}.")
            break
        else:
            print("\nPlease enter a 10-digit phone number.\n")
            continue
    except ValueError:
        print("\nInvalid input. Please enter a valid phone number.\n")

country_code = "+233"
# Out:
# Phone number received: 246089361.

# %%
import random

def verify_otp_simple():
    # Generate a 6-digit random OTP
    generated_otp = str(random.randint(100000, 999999))
    print(f"OTP sent to user: {generated_otp}") # Simulation

    # Get user input
    user_input = input("Please enter the 6-digit OTP: ")

    # Compare
    if user_input == generated_otp:
        return "Access Granted"
    else:
        return "Access Denied"

print(verify_otp_simple())
# Out:
# OTP sent to user: 351734
# Access Granted

# %%
if choice == 'Buyer':
    print('Hello, Buyer')
else:
    print('Hello, Farmer')
# Out:
# Hello, Farmer

# %% [markdown]
# ### Farmer Dashboard

# %%
service_option = ["Post Produce", "Manage Waste"]

# %% [markdown]
# ### Option 1 - Post Produce

# %%
# Crop Options
crop_type = ["Maize","Pepper","Onion","Tomato","Cassava","Sorghum","Pineapple","Ginger"]
# Harvest Status
harvested = ["Yes","No"]

# %%
while True:
    try:
        weeks_left = input("How many weeks to harvest? ")
        weeks_left = int(weeks_left)
        if weeks_left > 0:
            print(f"\nInput received: {weeks_left} week(s) left.")
            break
        else:
            print(f"Enter a valid number of weeks.")
            continue
    except ValueError:
        print("\nInvalid input. Please enter week(s) to harvest.\n")
        continue
# Out:
# Input received: 3 week(s) left.

# %%
# Sub Route Programming

# %%
# Save to database
import pandas as pd
# first_name, last_name, phone number, choice, service_option, crop_type

# %% [markdown]
# ### Option 2 - Manage Waste

# %%
# Crop Options
waste_type = ["Maize Stalks/Cobs",
              "Cassava Peels/Stems",
              "Rotten Bulk Produce",
              "Pineapple Crowns",
              "Sorghum Straw",
              "Animal Manure"]
# Harvest Status
intent = ["Learn","Sell"]

# %%
# Save to database
import pandas as pd
# first_name, last_name, phone number, choice, service_option, waste_type

# %% [markdown]
# ### Buyer Dashboard

# %%
service_option = ["Buy Produce", "Buy Waste"]

# %% [markdown]
# ### Option 1 - Buy Produce

# %%
crop_filter = ["Crop Type", "Region/District"]
view_feed = ["Show Photos", "Prices", "Harvest Status"]
mode_of_delivery = ["Free Pickup"]

# %% [markdown]
# ### Option 2 - Buy Waste

# %%
waste_filter = ["Waste Type", "Region/District"]
# Weight = Bags/Kgs/Tons
# Condition = Fresh/Dry
view_feed = ["Show Photos", "Weight", "Condition"]
mode_of_delivery = ["Free Pickup"]
