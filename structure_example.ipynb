# %% [raw]
# my_project/
# ├── .streamlit/             # Config and secrets (e.g., config.toml, secrets.toml)
# ├── data/                   # Raw or processed data files (CSV, JSON, etc.)
# ├── pages/                  # Additional app pages (automatically detected)
# │   ├── 01_Dashboard.py
# │   └── 02_Settings.py
# ├── src/                    # Non-Streamlit Python logic
# │   ├── __init__.py
# │   ├── utils.py            # Helper functions
# │   └── processing.py       # Data analysis or ML logic
# ├── tests/                  # Unit and integration tests
# ├── .env                    # Environment variables (local dev)
# ├── app.py                  # Main entry point (the "Home" page)
# ├── requirements.txt        # Python dependencies
# └── README.md               # Project documentation

# %%
my_project/
├── .streamlit/             # Config and secrets (e.g., config.toml, secrets.toml)
├── data/                   # Raw or processed data files (CSV, JSON, etc.)
├── pages/                  # Additional app pages (automatically detected)
│   ├── 01_Dashboard.py
│   └── 02_Settings.py
├── src/                    # Non-Streamlit Python logic
│   ├── __init__.py
│   ├── utils.py            # Helper functions
│   └── processing.py       # Data analysis or ML logic
├── tests/                  # Unit and integration tests
├── .env                    # Environment variables (local dev)
├── app.py                  # Main entry point (the "Home" page)
├── requirements.txt        # Python dependencies
└── README.md               # Project documentation

# %%
|- Welcome Message
|- Choice:
    - Farmer:
        - 
    - Service Provider:
        - Post-harvest
        - Aqua culture
    - Individual
